# %%
import sys
sys.path.append('../dashboards/')
sys.path.append('../../')
from conf.conf import conf
import JEFConsole
d = JEFConsole.JEFConsole()
d.showDashboard(conf.get("this_notebook_server","54.184.199.101:9999"))


#from IPython.core.display import HTML
#HTML("""<style>
#div.input {
#    display:none;
#}
#</style>""")


## TODO
# 1. Add System Configuration table which allows a user to edit objectConfiguration objects
# 2. jef kills jobs, automatically, in addition to the worker, when a halt command is recieved
# 3. Save memory/cpu use, over time, in the objectConfiguration
# 4. display the memory/cpu use as a graph for the user
# 5. display all jobs the user has, in the system
# 6. test all commands and generalize relevant code into bokehComponent.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9f80d95224ca> in <module>
#       5 import JEFConsole
#       6 d = JEFConsole.JEFConsole()
# ----> 7 d.showDashboard(conf.get("this_notebook_server","54.184.199.101:9999"))
#       8
#       9
#
# ~/bokehComponents/Dashboard.py in showDashboard(self, notebook_url, use_notebook)
#     103     def showDashboard(self, notebook_url=None,use_notebook = True):
#     104         app = self.createApplication(use_notebook )
# --> 105         doc = app.create_document()
#     106         if notebook_url is None:
#     107             raise Exception("No notebook URL defined!")
#
# ~/anaconda3/lib/python3.7/site-packages/bokeh/application/application.py in create_document(self)
#     165         '''
#     166         doc = Document()
# --> 167         self.initialize_document(doc)
#     168         return doc
#     169
#
# ...

# %%
import boto3  
from datetime import datetime, timedelta  
region = "us-east-1"  
ec2 = boto3.resource("ec2", region_name=region)  
def get_available_volumes():  
    available_volumes = ec2.volumes.filter(
        Filters=[{'Name': 'status', 'Values': ['available']}]
    )
    return available_volumes

for v in get_available_volumes():
    print(v)
