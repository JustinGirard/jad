# %%
import sys
sys.path.append('../dashboards/')
sys.path.append('../../')
from conf.conf import conf
import JEFConsole
d = JEFConsole.JEFConsole()
d.showDashboard(conf.get("this_notebook_server","54.184.199.101:9999"))


#from IPython.core.display import HTML
#HTML("""<style>
#div.input {
#    display:none;
#}
#</style>""")


## TODO
# 1. Add System Configuration table which allows a user to edit objectConfiguration objects
# 2. jef kills jobs, automatically, in addition to the worker, when a halt command is recieved
# 3. Save memory/cpu use, over time, in the objectConfiguration
# 4. display the memory/cpu use as a graph for the user
# 5. display all jobs the user has, in the system
# 6. test all commands and generalize relevant code into bokehComponent.
# Out:
# WARNING:bokeh.core.validation.check:W-1002 (EMPTY_LAYOUT): Layout has no children: Column(id='1043', ...)
# filter None
# {'detail_source': <JEFConsole.JobStarterQuery object at 0x7f630bae4518>}
# filter None
# <script src="http://dev.paxculturastudios.com:33823/autoload.js?bokeh-autoload-element=1111&bokeh-absolute-url=http://dev.paxculturastudios.com:33823&resources=none" id="1111"></script>
# WARNING:bokeh.core.validation.check:W-1002 (EMPTY_LAYOUT): Layout has no children: Column(id='1154', ...)
# filter None
# {'detail_source': <JEFConsole.JobStarterQuery object at 0x7f630ac2aef0>}
# filter None
# i-05e75507bcaf12912
# set_filter
# instanceId
# [<JEFConsole.JobStarterQuery object at 0x7f630ac2aef0>]
# instanceId
# dict_keys(['instanceId'])
# filter i-05e75507bcaf12912

# %%
import boto3  
from datetime import datetime, timedelta  
region = "us-east-1"  
ec2 = boto3.resource("ec2", region_name=region)  
def get_available_volumes():  
    available_volumes = ec2.volumes.filter(
        Filters=[{'Name': 'status', 'Values': ['available']}]
    )
    return available_volumes

for v in get_available_volumes():
    print(v)
